# %%
import pandas as pd

# %%
df = pd.read_csv('Global Open Data Barometer.csv')
# Out:
# /var/folders/__/8q6wtgc10gsdhs_z1lv_0r700000gn/T/ipykernel_1915/672431792.py:1: DtypeWarning: Columns (2,4,5,7,8,10,11,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('Global Open Data Barometer.csv')

# %%
# exploring

# %%
df[(df['hierarchy_level'] == 1) & (df['data_type'] == 'response')].groupby('country').mean()['score'].hist();

# %%
df[(df['hierarchy_level'] == 1) & (df['data_type'] == 'response')].groupby('country').mean()['score'].mean()
# Out:
# 38.517898137111324

# %%
df[(df['hierarchy_level'] == 1) & (df['data_type'] == 'response')].groupby('country', as_index = False).mean()[['country', 'score']].to_csv('CountryScore.csv')

# %%
countries_scores = df[(df['hierarchy_level'] == 1) & (df['data_type'] == 'response')].groupby('country', as_index = False).mean()

# %% [markdown]
# # Examples

# %%
countries_35_45 = list(countries_scores[(countries_scores['score'] > 35) & (countries_scores['score'] < 45)].country)#.sort_values('score').head(10)[['country', 'score']]

# %%
len(countries_35_45)
# Out:
# 20

# %%
countries_scores[(countries_scores['score'] < 15)].sort_values('score')
# Out:
#           country  hierarchy_level  response_value  normalized_response_value  \
# 100  Turkmenistan              1.0             NaN                        NaN
# 43          Haiti              1.0             NaN                        NaN
#
#      weight      score  row_order  question_order       wip       wib  \
# 100     NaN  10.524411        0.0    51301.615385  0.074074  0.018519
# 43      NaN  12.449250        0.0    51301.615385  0.074074  0.018519
#
#           wim
# 100  0.166667
# 43   0.166667

# %%
df[(df['hierarchy_level'] == 2) & 
   (df['data_type'] == 'response') & 
   (df['country'] == 'South Africa') & 
   (df['module'] == 'GOVERNANCE') &
   (df['question'] == 'Elements')]
# Out:
#       iso3       country      pillar      module                indicator_id  \
# 87700  ZAF  South Africa  Governance  GOVERNANCE            G.GOVERNANCE.DPL
# 87733  ZAF  South Africa  Governance  GOVERNANCE       G.GOVERNANCE.ODPOLICY
# 87754  ZAF  South Africa  Governance  GOVERNANCE    G.GOVERNANCE.DATASHARING
# 87772  ZAF  South Africa  Governance  GOVERNANCE     G.GOVERNANCE.DATAMANAGE
# 87795  ZAF  South Africa  Governance  GOVERNANCE           G.GOVERNANCE.LANG
# 87810  ZAF  South Africa  Governance  GOVERNANCE  G.GOVERNANCE.ACCESSIBILITY
#
#                                       indicator_name indicator_type  \
# 87700                Governance (G): Data protection        Primary
# 87733               Governance (G): Open data policy        Primary
# 87754        Governance (G): Data sharing frameworks        Primary
# 87772                Governance (G): Data management        Primary
# 87795       Governance (G): Language coverage & data        Primary
# ...

# %%
# saudi arabia

df[(df['hierarchy_level'] == 2) & 
   (df['data_type'] == 'response') & 
   (df['country'] == 'Saudi Arabia') & 
   (df['module'] == 'GOVERNANCE') &
   (df['question'] == 'Elements')]
# Out:
#        iso3       country      pillar      module                indicator_id  \
# 121263  SAU  Saudi Arabia  Governance  GOVERNANCE            G.GOVERNANCE.DPL
# 121289  SAU  Saudi Arabia  Governance  GOVERNANCE       G.GOVERNANCE.ODPOLICY
# 121311  SAU  Saudi Arabia  Governance  GOVERNANCE    G.GOVERNANCE.DATASHARING
# 121332  SAU  Saudi Arabia  Governance  GOVERNANCE     G.GOVERNANCE.DATAMANAGE
# 121354  SAU  Saudi Arabia  Governance  GOVERNANCE           G.GOVERNANCE.LANG
# 121367  SAU  Saudi Arabia  Governance  GOVERNANCE  G.GOVERNANCE.ACCESSIBILITY
#
#                                        indicator_name indicator_type  \
# 121263                Governance (G): Data protection        Primary
# 121289               Governance (G): Open data policy        Primary
# 121311        Governance (G): Data sharing frameworks        Primary
# 121332                Governance (G): Data management        Primary
# 121354       Governance (G): Language coverage & data        Primary
# ...

# %%
# mongolia

df[(df['hierarchy_level'] == 2) & 
   (df['data_type'] == 'response') & 
   (df['country'] == 'Mongolia') & 
   (df['module'] == 'GOVERNANCE') &
   (df['question'] == 'Elements')]
# Out:
#       iso3   country      pillar      module                indicator_id  \
# 68603  MNG  Mongolia  Governance  GOVERNANCE            G.GOVERNANCE.DPL
# 68634  MNG  Mongolia  Governance  GOVERNANCE       G.GOVERNANCE.ODPOLICY
# 68656  MNG  Mongolia  Governance  GOVERNANCE    G.GOVERNANCE.DATASHARING
# 68678  MNG  Mongolia  Governance  GOVERNANCE     G.GOVERNANCE.DATAMANAGE
# 68701  MNG  Mongolia  Governance  GOVERNANCE           G.GOVERNANCE.LANG
# 68716  MNG  Mongolia  Governance  GOVERNANCE  G.GOVERNANCE.ACCESSIBILITY
#
#                                       indicator_name indicator_type  \
# 68603                Governance (G): Data protection        Primary
# 68634               Governance (G): Open data policy        Primary
# 68656        Governance (G): Data sharing frameworks        Primary
# 68678                Governance (G): Data management        Primary
# 68701       Governance (G): Language coverage & data        Primary
# ...

# %%
# estonia

df[(df['hierarchy_level'] == 2) & 
   (df['data_type'] == 'response') & 
   (df['country'] == 'Estonia') & 
   (df['module'] == 'GOVERNANCE') &
   (df['question'] == 'Elements')]
# Out:
#       iso3  country      pillar      module                indicator_id  \
# 16708  EST  Estonia  Governance  GOVERNANCE            G.GOVERNANCE.DPL
# 16741  EST  Estonia  Governance  GOVERNANCE       G.GOVERNANCE.ODPOLICY
# 16764  EST  Estonia  Governance  GOVERNANCE    G.GOVERNANCE.DATASHARING
# 16790  EST  Estonia  Governance  GOVERNANCE     G.GOVERNANCE.DATAMANAGE
# 16809  EST  Estonia  Governance  GOVERNANCE           G.GOVERNANCE.LANG
# 16826  EST  Estonia  Governance  GOVERNANCE  G.GOVERNANCE.ACCESSIBILITY
#
#                                       indicator_name indicator_type  \
# 16708                Governance (G): Data protection        Primary
# 16741               Governance (G): Open data policy        Primary
# 16764        Governance (G): Data sharing frameworks        Primary
# 16790                Governance (G): Data management        Primary
# 16809       Governance (G): Language coverage & data        Primary
# ...

# %%
# a bit more on what these mean: OD Policy [relatively high], but huge disparities in other sectors

# %%
df[(df['hierarchy_level'] == 2) & 
   (df['data_type'] == 'response') & 
   (df['indicator_id'] == 'G.GOVERNANCE.ODPOLICY') & 
   (df['module'] == 'GOVERNANCE') &
   (df['question'] == 'Elements')]['score'].hist();

# %%
df[(df['hierarchy_level'] == 2) & 
   (df['data_type'] == 'response') & 
   (df['indicator_id'] == 'G.GOVERNANCE.DATASHARING') & 
   (df['module'] == 'GOVERNANCE') &
   (df['question'] == 'Elements')]['score'].hist();

# %%
df[(df['hierarchy_level'] == 2) & 
   (df['data_type'] == 'response') & 
   (df['module'] == 'GOVERNANCE') &
   (df['question'] == 'Elements')][['country', 'indicator_name', 'score']].to_csv('heatmap_data.csv')#.set_index('country').T

# %%
df[(df['hierarchy_level'] == 2) & 
   (df['data_type'] == 'response') & 
   (df['module'] == 'HEALTH & COVID-19') &
   (df['question'] == 'Elements')][['country', 'indicator_name', 'score']].to_csv('heatmap_data_covid.csv')

# %% [markdown]
# # Indices

# %%
df[(df['hierarchy_level'] == 1) & 
   (df['data_type'] == 'response') & 
  (df['indicator_name'] == 'Capability (C): Use of standards and methods in statistic offices')].groupby(['country']).mean()['score'].hist()
# Out:
# <AxesSubplot:>

# %%
df[(df['hierarchy_level'] == 2) & (df['question'] == 'Existence')].head()
# Out:
#    iso3 country      pillar      module              indicator_id  \
# 2   XKX  Kosovo  Governance  GOVERNANCE          G.GOVERNANCE.DPL
# 32  XKX  Kosovo  Governance  GOVERNANCE     G.GOVERNANCE.ODPOLICY
# 55  XKX  Kosovo  Governance  GOVERNANCE  G.GOVERNANCE.DATASHARING
# 76  XKX  Kosovo  Governance  GOVERNANCE   G.GOVERNANCE.DATAMANAGE
# 89  XKX  Kosovo  Governance  GOVERNANCE         G.GOVERNANCE.LANG
#
#                               indicator_name indicator_type  \
# 2            Governance (G): Data protection        Primary
# 32          Governance (G): Open data policy        Primary
# 55   Governance (G): Data sharing frameworks        Primary
# 76           Governance (G): Data management        Primary
# 89  Governance (G): Language coverage & data        Primary
#
#                  variable_name   question  hierarchy_level  ... score  \
# 2           G.GOVERNANCE.DPL.a  Existence                2  ...   1.0
# ...

# %%
df['module'].unique()
# Out:
# array(['GOVERNANCE', 'CAPABILITIES', 'COMPANY INFORMATION', 'LAND',
#        'POLITICAL INTEGRITY', 'PUBLIC FINANCE', 'PROCUREMENT',
#        'CLIMATE ACTION', 'HEALTH & COVID-19', nan], dtype=object)

# %%
df[(df['module'] == 'POLITICAL INTEGRITY') & 
   (df['data_type'] == 'response') & 
   (df['hierarchy_level'] == 1)].groupby(['country', 'indicator_name'], as_index = False).mean()[['country', 'indicator_name', 'score']].to_csv('CountryIndicator.csv')

# %%
df[(df['module'] == 'GOVERNANCE') & 
   (df['data_type'] == 'response') & 
   (df['hierarchy_level'] == 1)][['indicator_name', 'score', 'country']]
# Out:
#                                        indicator_name  score  country
# 0                     Governance (G): Data protection   72.0   Kosovo
# 26                   Governance (G): Open data policy   54.0   Kosovo
# 52            Governance (G): Data sharing frameworks   60.0   Kosovo
# 74                    Governance (G): Data management    0.0   Kosovo
# 87           Governance (G): Language coverage & data    0.0   Kosovo
# ...                                               ...    ...      ...
# 125109               Governance (G): Open data policy   80.0  Czechia
# 125135        Governance (G): Data sharing frameworks   18.0  Czechia
# 125155                Governance (G): Data management   14.0  Czechia
# 125173       Governance (G): Language coverage & data    0.0  Czechia
# 125188  Governance (G): Accessibility coverage & data   58.5  Czechia
#
# [654 rows x 3 columns]

# %%
df[(df['module'] == 'POLITICAL INTEGRITY') &
  (df['country'] == 'Albania')][['question', 'response', 'score']].loc[124573, 'question']
# Out:
# 'Historical data is available that allows users to track change over time.'

# %% [markdown]
# # Governance

# %%
df[(df['module'] == 'GOVERNANCE') & 
   (df['indicator_name'] == 'Governance (G): Data protection')
    & (df['question'].str.contains('location') == True)
   & (df['response'] == 'Yes')
  ].groupby('barometer_region').count()
# Out:
#                                                     iso3  country  pillar  \
# barometer_region
# Africa                                                 4        4       4
# European Union, United Kingdom, North America, ...    17       17      17
# Latin America and the Caribbean                        1        1       1
# South and East Asia                                    1        1       1
#
#                                                     module  indicator_id  \
# barometer_region
# Africa                                                   4             4
# European Union, United Kingdom, North America, ...      17            17
# Latin America and the Caribbean                          1             1
# South and East Asia                                      1             1
#
#                                                     indicator_name  \
# barometer_region
# Africa                                                           4
# ...

# %%
df[(df['module'] == 'GOVERNANCE') & 
   (df['indicator_name'] == 'Governance (G): Data protection')
    & (df['question'].str.contains('algorithmic') == True)
   & (df['response'] == 'Yes')
  ].groupby('barometer_region').count()
# Out:
#                                                     iso3  country  pillar  \
# barometer_region
# Africa                                                 5        5       5
# Eastern Europe and Central Asia                        2        2       2
# European Union, United Kingdom, North America, ...    20       20      20
# Latin America and the Caribbean                        1        1       1
# Middle East and North Africa                           1        1       1
# South and East Asia                                    2        2       2
#
#                                                     module  indicator_id  \
# barometer_region
# Africa                                                   5             5
# Eastern Europe and Central Asia                          2             2
# European Union, United Kingdom, North America, ...      20            20
# Latin America and the Caribbean                          1             1
# ...

# %%
df.loc[124317, 'response']
# Out:
# "Article 14 of the law 9887/2008\nAutomated Decision\n(Amended point 2, with law no.48/2012)\n1. Each person shall be entitled not to be subject to decisions, that cause legal effects on him\nor that influence him significantly and the decision is based only on the automatic\nprocessing of the data, which aim at assessing certain personal aspects related to him,\nparticularly his efficiency at work, his credibility or behaviour.\n2. A person may be subject to a decision taken under point 1 herein, when the decision:\na) is taken in the course of entering into or performance of a contract, provided the request\nfor entering into or the performance of the contract, lodged by the data subject, has been\nsatisfied, or if there are adequate measures to safe- guard his legitimate interests, such\nas the possibilities allowing him to point out his views;\nb) is authorized by a law which also lays down measures to safeguard the data subject's\nlegitimate interests"

# %%
df[(df['module'] == 'GOVERNANCE') & 
   (df['indicator_name'] == 'Governance (G): Language coverage & data') &
   (df['question'] == 'Existence')]
# Out:
#        iso3             country      pillar      module       indicator_id  \
# 89      XKX              Kosovo  Governance  GOVERNANCE  G.GOVERNANCE.LANG
# 1165    BHS             Bahamas  Governance  GOVERNANCE  G.GOVERNANCE.LANG
# 2258    BLZ              Belize  Governance  GOVERNANCE  G.GOVERNANCE.LANG
# 3428    DOM  Dominican Republic  Governance  GOVERNANCE  G.GOVERNANCE.LANG
# 4570    GUY              Guyana  Governance  GOVERNANCE  G.GOVERNANCE.LANG
# ...     ...                 ...         ...         ...                ...
# 121348  SAU        Saudi Arabia  Governance  GOVERNANCE  G.GOVERNANCE.LANG
# 122366  QAT               Qatar  Governance  GOVERNANCE  G.GOVERNANCE.LANG
# 123369  BHR             Bahrain  Governance  GOVERNANCE  G.GOVERNANCE.LANG
# 124389  ALB             Albania  Governance  GOVERNANCE  G.GOVERNANCE.LANG
# 125177  CZE             Czechia  Governance  GOVERNANCE  G.GOVERNANCE.LANG
#
#                                   indicator_name indicator_type  \
# ...

# %% [markdown]
# # COVID

# %%
df[(df['module'] == 'HEALTH & COVID-19') &
   (df['data_type'] == 'response') & 
  (df['indicator_name'] == 'Availability (H): Vital statistics') & 
  (df['question'].str.contains('There are accessible and open official tools available to help users explore data') == True)].groupby(['response']).count()
# Out:
#            iso3  country  pillar  module  indicator_id  indicator_name  \
# response
# No           61       61      61      61            61              61
# Partially    10       10      10      10            10              10
# Yes          38       38      38      38            38              38
#
#            indicator_type  variable_name  question  hierarchy_level  ...  \
# response                                                             ...
# No                     61             61        61               61  ...
# Partially              10             10        10               10  ...
# Yes                    38             38        38               38  ...
#
#            score  parent  row_order  question_order  wip  wib  wim  \
# response
# No            61      61         61              61   61   61   61
# Partially     10      10         10              10   10   10   10
# Yes           38      38         38              38   38   38   38
#
# ...

# %%
df[(df['module'] == 'HEALTH & COVID-19') &
   (df['data_type'] == 'response') & 
  (df['indicator_name'] == 'Availability (H): Vaccination (COVID-19)') & 
  (df['question'].str.contains('There are accessible and open official tools available to help users explore data') == True)].groupby(['response']).count()
# Out:
#            iso3  country  pillar  module  indicator_id  indicator_name  \
# response
# No           63       63      63      63            63              63
# Partially     6        6       6       6             6               6
# Yes          40       40      40      40            40              40
#
#            indicator_type  variable_name  question  hierarchy_level  ...  \
# response                                                             ...
# No                     63             63        63               63  ...
# Partially               6              6         6                6  ...
# Yes                    40             40        40               40  ...
#
#            score  parent  row_order  question_order  wip  wib  wim  \
# response
# No            62      63         63              63   63   63   63
# Partially      6       6          6               6    6    6    6
# Yes           40      40         40              40   40   40   40
#
# ...

# %%
df[(df['module'] == 'HEALTH & COVID-19') &
   (df['data_type'] == 'response') & 
  (df['indicator_name'] == 'Availability (H): Vaccination (COVID-19)') & 
  (df['question'].str.contains('Data is provided in machine-readable') == True)].groupby(['response']).count()
# Out:
#            iso3  country  pillar  module  indicator_id  indicator_name  \
# response
# No           57       57      57      57            57              57
# Partially     3        3       3       3             3               3
# Yes          49       49      49      49            49              49
#
#            indicator_type  variable_name  question  hierarchy_level  ...  \
# response                                                             ...
# No                     57             57        57               57  ...
# Partially               3              3         3                3  ...
# Yes                    49             49        49               49  ...
#
#            score  parent  row_order  question_order  wip  wib  wim  \
# response
# No            55      57         57              57   57   57   57
# Partially      3       3          3               3    3    3    3
# Yes           49      49         49              49   49   49   49
#
# ...
